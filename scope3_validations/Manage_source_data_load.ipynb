# %%
# %sql
select distinct month, year
from gmsehs_us_lake.ehs_scope3_spendviz_sapbw_combined_view

# %%
# %sql
select distinct mth_val, yr_val
from gmsehs_us_hub.txn_ehs_scope3_spendviz_sapbw_combined_data
order by 2 ,1 asc

# %%
# %sql
select distinct src_val , yr_val
from gmsehs_us_hub.txn_ehs_scope3_spendviz_sapbw_combined_data
order by 1

# %%
# %sql
select *
from gmsehs_us_hub.txn_ehs_scope3_spendviz_sapbw_combined_data

# %% [markdown]
# # Check totals from Archived

# %%
# %sql
select *
from gmsehs_us_hub.spendviz_sapbw_history_totals

# %%
# %sql
select *
from

# %% [markdown]
# # Describe history

# %%
# %sql
DESCRIBE HISTORY gmsehs_us_hub.txn_ehs_scope3_spendviz_sapbw_combined_data

# %% [markdown]
# # Saved archied_data

# %%
# %sql
select distinct mth_val, src_val, yr_val
from gmsehs_us_hub.sapbw_history_archive
where not (yr_val in (2025) and mth_val in ('4', '5','6','7','8', '9'))
order by yr_val, INT(mth_val) asc

# %%
# %sql
select distinct mth_val, src_val, yr_val
from gmsehs_us_hub.spendviz_sapbw_history_archive

# %%
# %sql
select *
from gmsehs_us_hub.sapbw_history_archive

# %% [markdown]
# # Time travel

# %%
# %sql
select max(Aud_Crt_Dts)
from gmsehs_us_hub.txn_ehs_scope3_spendviz_sapbw_combined_data
version as of 93

# %% [markdown]
# # Append missing months for BW

# %%
# %sql
INSERT INTO gmsehs_us_hub.txn_ehs_scope3_spendviz_sapbw_combined_data
SELECT *
FROM gmsehs_us_hub.sapbw_history_archive
where
