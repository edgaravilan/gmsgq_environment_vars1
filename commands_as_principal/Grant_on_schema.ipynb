# %%
workspace = spark.conf.get("spark.databricks.workspaceUrl").split('.')[0].split('-')[1]
print("workspace : ", workspace)
if workspace == "usprd":
    CTLG = "us_gmsgq_prd"
elif workspace == "ustst":
    CTLG = "us_gmsgq_tst"
elif workspace == "usdev":
    CTLG = "us_gmsgq_dev"

# Just use current env catalog
spark.sql(f"USE CATALOG {CTLG}")

# %%
# %sql
GRANT CREATE TABLE ON SCHEMA gmsehs_us_mart TO `edgar.avilan@takeda.com`;

# %%
# %sql
GRANT CREATE TABLE ON SCHEMA gmsehs_us_hub TO `edgar.avilan@takeda.com`;

# %%
# %sql
GRANT CREATE TABLE ON SCHEMA gmsehs_us_lake TO `edgar.avilan@takeda.com`;
