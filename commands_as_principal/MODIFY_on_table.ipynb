# %%
workspace = spark.conf.get("spark.databricks.workspaceUrl").split('.')[0].split('-')[1]
print("workspace : ", workspace)
if workspace == "usprd":
    CTLG = "us_gmsgq_prd"
elif workspace == "ustst":
    CTLG = "us_gmsgq_tst"
elif workspace == "usdev":
    CTLG = "us_gmsgq_dev"

# Just use current env catalog
spark.sql(f"USE CATALOG {CTLG}")

# %%
# %sql
--Commit again
GRANT MODIFY ON TABLE gmsehs_us_hub.txn_ehs_scope3_spendviz_sapbw_combined_data TO `edgar.avilan@takeda.com`;
