# %%
workspace = spark.conf.get("spark.databricks.workspaceUrl").split('.')[0].split('-')[1]
print("workspace : ", workspace)
if workspace == "usprd":
    CTLG = "us_gmsgq_prd"
elif workspace == "ustst":
    CTLG = "us_gmsgq_tst"
elif workspace == "usdev":
    CTLG = "us_gmsgq_dev"

# Just use current env catalog
spark.sql(f"USE CATALOG {CTLG}")

# %%
# %sql
CREATE TABLE gmsehs_us_lake.sample_table_check1 (
    id INT,
    name STRING,
    created_date DATE
);

# %%
# %sql
select *
from gmsehs_us_lake.sample_table_check1

# %%
# %sql
drop table gmsehs_us_lake.sample_table_check1

# %%
# %sql
select *
from `us_gmsgq_dev`.`gmsehs_us_lake`.`dbt_expectations_source_expect_9e62b3c554026dddd778301bcba8bd26`

# %%
# %sql
select * 
from `us_gmsgq_dev`.`gmsehs_us_lake`.`source_unique_gmsehs_us_lake_e_5e03c6e50182035ad4c96ff31150805f`
